# %% [markdown]
# ## Policy gradient using REINFORCE algorithm
#
# In this demo we create a multi-layer perceptron using tensorflow and train it to estimate our policy for the cart-pole environment in openai gym.

# %%
import tensorflow as tf
import numpy as np
import gym

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped
# Policy gradient has high variance, seed for reproducability
env.seed(1)
# Out:
# /home/peerless/anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# [1]

# %%
## ENVIRONMENT Hyperparameters
state_size = 4
action_size = env.action_space.n

## TRAINING Hyperparameters
max_episodes = 300
learning_rate = 0.01
gamma = 0.95 # Discount rate

# %%
def discount_and_normalize_rewards(episode_rewards):
    discounted_episode_rewards = np.zeros_like(episode_rewards)
    cumulative = 0.0
    for i in reversed(range(len(episode_rewards))):
        cumulative = cumulative * gamma + episode_rewards[i]
        discounted_episode_rewards[i] = cumulative
    
    mean = np.mean(discounted_episode_rewards)
    std = np.std(discounted_episode_rewards)
    discounted_episode_rewards = (discounted_episode_rewards - mean) / (std)
    
    return discounted_episode_rewards

# %%
with tf.name_scope("inputs"):
    input_ = tf.placeholder(tf.float32, [None, state_size], name="input_")
    actions = tf.placeholder(tf.int32, [None, action_size], name="actions")
    discounted_episode_rewards_ = tf.placeholder(tf.float32, [None,], name="discounted_episode_rewards")
    
    # Add this placeholder for having this variable in tensorboard
    mean_reward_ = tf.placeholder(tf.float32 , name="mean_reward")

    with tf.name_scope("fc1"):
        fc1 = tf.contrib.layers.fully_connected(inputs = input_,
                                                num_outputs = 10,
                                                activation_fn=tf.nn.relu,
                                                weights_initializer=tf.contrib.layers.xavier_initializer())

    with tf.name_scope("fc2"):
        fc2 = tf.contrib.layers.fully_connected(inputs = fc1,
                                                num_outputs = action_size,
                                                activation_fn= tf.nn.relu,
                                                weights_initializer=tf.contrib.layers.xavier_initializer())
    
    with tf.name_scope("fc3"):
        fc3 = tf.contrib.layers.fully_connected(inputs = fc2,
                                                num_outputs = action_size,
                                                activation_fn= None,
                                                weights_initializer=tf.contrib.layers.xavier_initializer())

    with tf.name_scope("softmax"):
        action_distribution = tf.nn.softmax(fc3)

    with tf.name_scope("loss"):
        # tf.nn.softmax_cross_entropy_with_logits computes the cross entropy of the result after applying the softmax function
        # If you have single-class labels, where an object can only belong to one class, you might now consider using 
        # tf.nn.sparse_softmax_cross_entropy_with_logits so that you don't have to convert your labels to a dense one-hot array. 
        neg_log_prob = tf.nn.softmax_cross_entropy_with_logits_v2(logits = fc3, labels = actions)
        loss = tf.reduce_mean(neg_log_prob * discounted_episode_rewards_) 
        
    
    with tf.name_scope("train"):
        train_opt = tf.train.AdamOptimizer(learning_rate).minimize(loss)

# %%
allRewards = []
total_rewards = 0
maximumRewardRecorded = 0
episode = 0
episode_states, episode_actions, episode_rewards = [],[],[]

saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for episode in range(max_episodes):
        
        episode_rewards_sum = 0

        # Launch the game
        state = env.reset()
        
        #env.render()
           
        while True:
            
            # Choose action a, remember WE'RE NOT IN A DETERMINISTIC ENVIRONMENT, WE'RE OUTPUT PROBABILITIES.
            action_probability_distribution = sess.run(action_distribution, feed_dict={input_: state.reshape([1,4])})
            
            action = np.random.choice(range(action_probability_distribution.shape[1]), p=action_probability_distribution.ravel())  # select action w.r.t the actions prob

            # Perform a
            new_state, reward, done, info = env.step(action)

            # Store s, a, r
            episode_states.append(state)
                        
            # For actions because we output only one (the index) we need 2 (1 is for the action taken)
            # We need [0., 1.] (if we take right) not just the index
            action_ = np.zeros(action_size)
            action_[action] = 1
            
            episode_actions.append(action_)
            
            episode_rewards.append(reward)
            if done:
                # Calculate sum reward
                episode_rewards_sum = np.sum(episode_rewards)
                
                allRewards.append(episode_rewards_sum)
                
                total_rewards = np.sum(allRewards)
                
                # Mean reward
                mean_reward = np.divide(total_rewards, episode+1)
                
                
                maximumRewardRecorded = np.amax(allRewards)
                
                print("==========================================")
                print("Episode: ", episode)
                print("Reward: ", episode_rewards_sum)
                print("Mean Reward", mean_reward)
                print("Max reward so far: ", maximumRewardRecorded)
                
                # Calculate discounted reward
                discounted_episode_rewards = discount_and_normalize_rewards(episode_rewards)
                                
                # Feedforward, gradient and backpropagation
                loss_, _ = sess.run([loss, train_opt], feed_dict={input_: np.vstack(np.array(episode_states)),
                                                                 actions: np.vstack(np.array(episode_actions)),
                                                                 discounted_episode_rewards_: discounted_episode_rewards 
                                                                })

            
                
                # Reset the transition stores
                episode_states, episode_actions, episode_rewards = [],[],[]
                
                break
            
            state = new_state
        
        # Save Model
        if episode % 100 == 0:
            saver.save(sess, "./models/model.ckpt")
            print("Model saved")
# Out:
# ==========================================
# Episode:  0
# Reward:  11.0
# Mean Reward 11.0
# Max reward so far:  11.0
# Model saved
# ==========================================
# Episode:  1
# Reward:  11.0
# Mean Reward 11.0
# Max reward so far:  11.0
# ==========================================
# Episode:  2
# Reward:  17.0
# Mean Reward 13.0
# Max reward so far:  17.0
# ==========================================
# Episode:  3
# Reward:  20.0
# Mean Reward 14.75
# Max reward so far:  20.0
# ==========================================
# Episode:  4
# Reward:  16.0
# Mean Reward 15.0
# Max reward so far:  20.0
# ==========================================
# Episode:  5
# Reward:  11.0
# Mean Reward 14.333333333333334
# Max reward so far:  20.0
# ==========================================
# Episode:  6
# Reward:  21.0
# Mean Reward 15.285714285714286
# Max reward so far:  21.0
# ==========================================
# Episode:  7
# Reward:  12.0
# Mean Reward 14.875
# Max reward so far:  21.0
# ==========================================
# Episode:  8
# Reward:  37.0
# Mean Reward 17.333333333333332
# Max reward so far:  37.0
# ==========================================
# Episode:  9
# Reward:  18.0
# Mean Reward 17.4
# Max reward so far:  37.0
# ==========================================
# Episode:  10
# Reward:  20.0
# Mean Reward 17.636363636363637
# Max reward so far:  37.0
# ==========================================
# Episode:  11
# Reward:  24.0
# Mean Reward 18.166666666666668
# Max reward so far:  37.0
# ==========================================
# Episode:  12
# Reward:  46.0
# Mean Reward 20.307692307692307
# Max reward so far:  46.0
# ==========================================
# Episode:  13
# Reward:  9.0
# Mean Reward 19.5
# Max reward so far:  46.0
# ==========================================
# Episode:  14
# Reward:  14.0
# Mean Reward 19.133333333333333
# Max reward so far:  46.0
# ==========================================
# Episode:  15
# Reward:  19.0
# Mean Reward 19.125
# Max reward so far:  46.0
# ==========================================
# Episode:  16
# Reward:  24.0
# Mean Reward 19.41176470588235
# Max reward so far:  46.0
# ==========================================
# Episode:  17
# Reward:  17.0
# Mean Reward 19.27777777777778
# Max reward so far:  46.0
# ==========================================
# Episode:  18
# Reward:  21.0
# Mean Reward 19.36842105263158
# Max reward so far:  46.0
# ==========================================
# Episode:  19
# Reward:  14.0
# Mean Reward 19.1
# Max reward so far:  46.0
# ==========================================
# Episode:  20
# Reward:  22.0
# Mean Reward 19.238095238095237
# Max reward so far:  46.0
# ==========================================
# Episode:  21
# Reward:  13.0
# Mean Reward 18.954545454545453
# Max reward so far:  46.0
# ==========================================
# Episode:  22
# Reward:  21.0
# Mean Reward 19.043478260869566
# Max reward so far:  46.0
# ==========================================
# Episode:  23
# Reward:  66.0
# Mean Reward 21.0
# Max reward so far:  66.0
# ==========================================
# Episode:  24
# Reward:  32.0
# Mean Reward 21.44
# Max reward so far:  66.0
# ==========================================
# Episode:  25
# Reward:  38.0
# Mean Reward 22.076923076923077
# Max reward so far:  66.0
# ==========================================
# Episode:  26
# Reward:  67.0
# Mean Reward 23.74074074074074
# Max reward so far:  67.0
# ==========================================
# Episode:  27
# Reward:  15.0
# Mean Reward 23.428571428571427
# Max reward so far:  67.0
# ==========================================
# Episode:  28
# Reward:  12.0
# Mean Reward 23.03448275862069
# Max reward so far:  67.0
# ==========================================
# Episode:  29
# Reward:  21.0
# Mean Reward 22.966666666666665
# Max reward so far:  67.0
# ==========================================
# Episode:  30
# Reward:  49.0
# Mean Reward 23.806451612903224
# Max reward so far:  67.0
# ==========================================
# Episode:  31
# Reward:  17.0
# Mean Reward 23.59375
# Max reward so far:  67.0
# ==========================================
# Episode:  32
# Reward:  16.0
# Mean Reward 23.363636363636363
# Max reward so far:  67.0
# ==========================================
# Episode:  33
# Reward:  12.0
# Mean Reward 23.029411764705884
# Max reward so far:  67.0
# ==========================================
# Episode:  34
# Reward:  16.0
# Mean Reward 22.82857142857143
# Max reward so far:  67.0
# ==========================================
# Episode:  35
# Reward:  21.0
# Mean Reward 22.77777777777778
# Max reward so far:  67.0
# ==========================================
# Episode:  36
# Reward:  25.0
# Mean Reward 22.83783783783784
# Max reward so far:  67.0
# ==========================================
# Episode:  37
# Reward:  21.0
# Mean Reward 22.789473684210527
# Max reward so far:  67.0
# ==========================================
# Episode:  38
# Reward:  12.0
# Mean Reward 22.512820512820515
# Max reward so far:  67.0
# ==========================================
# Episode:  39
# Reward:  74.0
# Mean Reward 23.8
# Max reward so far:  74.0
# ==========================================
# Episode:  40
# Reward:  15.0
# Mean Reward 23.585365853658537
# Max reward so far:  74.0
# ==========================================
# Episode:  41
# Reward:  16.0
# Mean Reward 23.404761904761905
# Max reward so far:  74.0
# ==========================================
# Episode:  42
# Reward:  16.0
# Mean Reward 23.232558139534884
# Max reward so far:  74.0
# ==========================================
# Episode:  43
# Reward:  18.0
# Mean Reward 23.113636363636363
# Max reward so far:  74.0
# ==========================================
# Episode:  44
# Reward:  17.0
# Mean Reward 22.977777777777778
# Max reward so far:  74.0
# ==========================================
# Episode:  45
# Reward:  29.0
# Mean Reward 23.108695652173914
# Max reward so far:  74.0
# ==========================================
# Episode:  46
# Reward:  16.0
# Mean Reward 22.95744680851064
# Max reward so far:  74.0
# ==========================================
# Episode:  47
# Reward:  12.0
# Mean Reward 22.729166666666668
# Max reward so far:  74.0
# ==========================================
# Episode:  48
# Reward:  39.0
# Mean Reward 23.06122448979592
# Max reward so far:  74.0
# ==========================================
# Episode:  49
# Reward:  16.0
# Mean Reward 22.92
# Max reward so far:  74.0
# ==========================================
# Episode:  50
# Reward:  14.0
# Mean Reward 22.745098039215687
# Max reward so far:  74.0
# ==========================================
# Episode:  51
# Reward:  25.0
# Mean Reward 22.78846153846154
# Max reward so far:  74.0
# ==========================================
# Episode:  52
# Reward:  20.0
# Mean Reward 22.735849056603772
# Max reward so far:  74.0
# ==========================================
# Episode:  53
# Reward:  15.0
# Mean Reward 22.59259259259259
# Max reward so far:  74.0
# ==========================================
# Episode:  54
# Reward:  30.0
# Mean Reward 22.727272727272727
# Max reward so far:  74.0
# ==========================================
# Episode:  55
# Reward:  30.0
# Mean Reward 22.857142857142858
# Max reward so far:  74.0
# ==========================================
# Episode:  56
# Reward:  29.0
# Mean Reward 22.964912280701753
# Max reward so far:  74.0
# ==========================================
# Episode:  57
# Reward:  25.0
# Mean Reward 23.0
# Max reward so far:  74.0
# ==========================================
# Episode:  58
# Reward:  14.0
# Mean Reward 22.847457627118644
# Max reward so far:  74.0
# ==========================================
# Episode:  59
# Reward:  24.0
# Mean Reward 22.866666666666667
# Max reward so far:  74.0
# ==========================================
# Episode:  60
# Reward:  29.0
# Mean Reward 22.9672131147541
# Max reward so far:  74.0
# ==========================================
# Episode:  61
# Reward:  14.0
# Mean Reward 22.822580645161292
# Max reward so far:  74.0
# ==========================================
# Episode:  62
# Reward:  15.0
# Mean Reward 22.6984126984127
# Max reward so far:  74.0
# ==========================================
# Episode:  63
# Reward:  35.0
# Mean Reward 22.890625
# Max reward so far:  74.0
# ==========================================
# Episode:  64
# Reward:  13.0
# Mean Reward 22.73846153846154
# Max reward so far:  74.0
# ==========================================
# Episode:  65
# Reward:  22.0
# Mean Reward 22.727272727272727
# Max reward so far:  74.0
# ==========================================
# Episode:  66
# Reward:  25.0
# Mean Reward 22.761194029850746
# Max reward so far:  74.0
# ==========================================
# Episode:  67
# Reward:  55.0
# Mean Reward 23.235294117647058
# Max reward so far:  74.0
# ==========================================
# Episode:  68
# Reward:  15.0
# Mean Reward 23.115942028985508
# Max reward so far:  74.0
# ==========================================
# Episode:  69
# Reward:  14.0
# Mean Reward 22.985714285714284
# Max reward so far:  74.0
# ==========================================
# Episode:  70
# Reward:  31.0
# Mean Reward 23.098591549295776
# Max reward so far:  74.0
# ==========================================
# Episode:  71
# Reward:  11.0
# Mean Reward 22.930555555555557
# Max reward so far:  74.0
# ==========================================
# Episode:  72
# Reward:  11.0
# Mean Reward 22.767123287671232
# Max reward so far:  74.0
# ==========================================
# Episode:  73
# Reward:  37.0
# Mean Reward 22.95945945945946
# Max reward so far:  74.0
# ==========================================
# Episode:  74
# Reward:  17.0
# Mean Reward 22.88
# Max reward so far:  74.0
# ==========================================
# Episode:  75
# Reward:  11.0
# Mean Reward 22.723684210526315
# Max reward so far:  74.0
# ==========================================
# Episode:  76
# Reward:  15.0
# Mean Reward 22.623376623376622
# Max reward so far:  74.0
# ==========================================
# Episode:  77
# Reward:  23.0
# Mean Reward 22.628205128205128
# Max reward so far:  74.0
# ==========================================
# Episode:  78
# Reward:  24.0
# Mean Reward 22.645569620253166
# Max reward so far:  74.0
# ==========================================
# Episode:  79
# Reward:  21.0
# Mean Reward 22.625
# Max reward so far:  74.0
# ==========================================
# Episode:  80
# Reward:  33.0
# Mean Reward 22.753086419753085
# Max reward so far:  74.0
# ==========================================
# Episode:  81
# Reward:  21.0
# Mean Reward 22.73170731707317
# Max reward so far:  74.0
# ==========================================
# Episode:  82
# Reward:  45.0
# Mean Reward 23.0
# Max reward so far:  74.0
# ==========================================
# Episode:  83
# Reward:  36.0
# Mean Reward 23.154761904761905
# Max reward so far:  74.0
# ==========================================
# Episode:  84
# Reward:  18.0
# Mean Reward 23.094117647058823
# Max reward so far:  74.0
# ==========================================
# Episode:  85
# Reward:  41.0
# Mean Reward 23.302325581395348
# Max reward so far:  74.0
# ==========================================
# Episode:  86
# Reward:  37.0
# Mean Reward 23.45977011494253
# Max reward so far:  74.0
# ==========================================
# Episode:  87
# Reward:  65.0
# Mean Reward 23.931818181818183
# Max reward so far:  74.0
# ==========================================
# Episode:  88
# Reward:  10.0
# Mean Reward 23.775280898876403
# Max reward so far:  74.0
# ==========================================
# Episode:  89
# Reward:  22.0
# Mean Reward 23.755555555555556
# Max reward so far:  74.0
# ==========================================
# Episode:  90
# Reward:  32.0
# Mean Reward 23.846153846153847
# Max reward so far:  74.0
# ==========================================
# Episode:  91
# Reward:  18.0
# Mean Reward 23.782608695652176
# Max reward so far:  74.0
# ==========================================
# Episode:  92
# Reward:  27.0
# Mean Reward 23.817204301075268
# Max reward so far:  74.0
# ==========================================
# Episode:  93
# Reward:  12.0
# Mean Reward 23.69148936170213
# Max reward so far:  74.0
# ==========================================
# Episode:  94
# Reward:  14.0
# Mean Reward 23.589473684210525
# Max reward so far:  74.0
# ==========================================
# Episode:  95
# Reward:  29.0
# Mean Reward 23.645833333333332
# Max reward so far:  74.0
# ==========================================
# Episode:  96
# Reward:  26.0
# Mean Reward 23.670103092783506
# Max reward so far:  74.0
# ==========================================
# Episode:  97
# Reward:  15.0
# Mean Reward 23.581632653061224
# Max reward so far:  74.0
# ==========================================
# Episode:  98
# Reward:  21.0
# Mean Reward 23.555555555555557
# Max reward so far:  74.0
# ==========================================
# Episode:  99
# Reward:  19.0
# Mean Reward 23.51
# Max reward so far:  74.0
# ==========================================
# Episode:  100
# Reward:  27.0
# Mean Reward 23.544554455445546
# Max reward so far:  74.0
# Model saved
# ==========================================
# Episode:  101
# Reward:  33.0
# Mean Reward 23.637254901960784
# Max reward so far:  74.0
# ==========================================
# Episode:  102
# Reward:  26.0
# Mean Reward 23.660194174757283
# Max reward so far:  74.0
# ==========================================
# Episode:  103
# Reward:  15.0
# Mean Reward 23.576923076923077
# Max reward so far:  74.0
# ==========================================
# Episode:  104
# Reward:  22.0
# Mean Reward 23.561904761904763
# Max reward so far:  74.0
# ==========================================
# Episode:  105
# Reward:  17.0
# Mean Reward 23.5
# Max reward so far:  74.0
# ==========================================
# Episode:  106
# Reward:  63.0
# Mean Reward 23.869158878504674
# Max reward so far:  74.0
# ==========================================
# Episode:  107
# Reward:  24.0
# Mean Reward 23.87037037037037
# Max reward so far:  74.0
# ==========================================
# Episode:  108
# Reward:  21.0
# Mean Reward 23.844036697247706
# Max reward so far:  74.0
# ==========================================
# Episode:  109
# Reward:  14.0
# Mean Reward 23.754545454545454
# Max reward so far:  74.0
# ==========================================
# Episode:  110
# Reward:  22.0
# Mean Reward 23.73873873873874
# Max reward so far:  74.0
# ==========================================
# Episode:  111
# Reward:  25.0
# Mean Reward 23.75
# Max reward so far:  74.0
# ==========================================
# Episode:  112
# Reward:  27.0
# Mean Reward 23.778761061946902
# Max reward so far:  74.0
# ==========================================
# Episode:  113
# Reward:  64.0
# Mean Reward 24.13157894736842
# Max reward so far:  74.0
# ==========================================
# Episode:  114
# Reward:  14.0
# Mean Reward 24.043478260869566
# Max reward so far:  74.0
# ==========================================
# Episode:  115
# Reward:  19.0
# Mean Reward 24.0
# Max reward so far:  74.0
# ==========================================
# Episode:  116
# Reward:  21.0
# Mean Reward 23.974358974358974
# Max reward so far:  74.0
# ==========================================
# Episode:  117
# Reward:  16.0
# Mean Reward 23.906779661016948
# Max reward so far:  74.0
# ==========================================
# Episode:  118
# Reward:  18.0
# Mean Reward 23.857142857142858
# Max reward so far:  74.0
# ==========================================
# Episode:  119
# Reward:  23.0
# Mean Reward 23.85
# Max reward so far:  74.0
# ==========================================
# Episode:  120
# Reward:  18.0
# Mean Reward 23.801652892561982
# Max reward so far:  74.0
# ==========================================
# Episode:  121
# Reward:  26.0
# Mean Reward 23.81967213114754
# Max reward so far:  74.0
# ==========================================
# Episode:  122
# Reward:  37.0
# Mean Reward 23.926829268292682
# Max reward so far:  74.0
# ==========================================
# Episode:  123
# Reward:  17.0
# Mean Reward 23.870967741935484
# Max reward so far:  74.0
# ==========================================
# Episode:  124
# Reward:  44.0
# Mean Reward 24.032
# Max reward so far:  74.0
# ==========================================
# Episode:  125
# Reward:  21.0
# Mean Reward 24.00793650793651
# Max reward so far:  74.0
# ==========================================
# Episode:  126
# Reward:  12.0
# Mean Reward 23.913385826771652
# Max reward so far:  74.0
# ==========================================
# Episode:  127
# Reward:  22.0
# Mean Reward 23.8984375
# Max reward so far:  74.0
# ==========================================
# Episode:  128
# Reward:  36.0
# Mean Reward 23.992248062015506
# Max reward so far:  74.0
# ==========================================
# Episode:  129
# Reward:  16.0
# Mean Reward 23.93076923076923
# Max reward so far:  74.0
# ==========================================
# Episode:  130
# Reward:  19.0
# Mean Reward 23.893129770992367
# Max reward so far:  74.0
# ==========================================
# Episode:  131
# Reward:  15.0
# Mean Reward 23.825757575757574
# Max reward so far:  74.0
# ==========================================
# Episode:  132
# Reward:  22.0
# Mean Reward 23.81203007518797
# Max reward so far:  74.0
# ==========================================
# Episode:  133
# Reward:  37.0
# Mean Reward 23.91044776119403
# Max reward so far:  74.0
# ==========================================
# Episode:  134
# Reward:  32.0
# Mean Reward 23.97037037037037
# Max reward so far:  74.0
# ==========================================
# Episode:  135
# Reward:  17.0
# Mean Reward 23.919117647058822
# Max reward so far:  74.0
# ==========================================
# Episode:  136
# Reward:  19.0
# Mean Reward 23.883211678832115
# Max reward so far:  74.0
# ==========================================
# Episode:  137
# Reward:  31.0
# Mean Reward 23.934782608695652
# Max reward so far:  74.0
# ==========================================
# Episode:  138
# Reward:  11.0
# Mean Reward 23.841726618705035
# Max reward so far:  74.0
# ==========================================
# Episode:  139
# Reward:  22.0
# Mean Reward 23.82857142857143
# Max reward so far:  74.0
# ==========================================
# Episode:  140
# Reward:  29.0
# Mean Reward 23.865248226950353
# Max reward so far:  74.0
# ==========================================
# Episode:  141
# Reward:  17.0
# Mean Reward 23.816901408450704
# Max reward so far:  74.0
# ==========================================
# Episode:  142
# Reward:  27.0
# Mean Reward 23.83916083916084
# Max reward so far:  74.0
# ==========================================
# Episode:  143
# Reward:  32.0
# Mean Reward 23.895833333333332
# Max reward so far:  74.0
# ==========================================
# Episode:  144
# Reward:  22.0
# Mean Reward 23.882758620689657
# Max reward so far:  74.0
# ==========================================
# Episode:  145
# Reward:  36.0
# Mean Reward 23.965753424657535
# Max reward so far:  74.0
# ==========================================
# Episode:  146
# Reward:  22.0
# Mean Reward 23.952380952380953
# Max reward so far:  74.0
# ==========================================
# Episode:  147
# Reward:  39.0
# Mean Reward 24.054054054054053
# Max reward so far:  74.0
# ==========================================
# Episode:  148
# Reward:  34.0
# Mean Reward 24.120805369127517
# Max reward so far:  74.0
# ==========================================
# Episode:  149
# Reward:  70.0
# Mean Reward 24.426666666666666
# Max reward so far:  74.0
# ==========================================
# Episode:  150
# Reward:  48.0
# Mean Reward 24.582781456953644
# Max reward so far:  74.0
# ==========================================
# Episode:  151
# Reward:  18.0
# Mean Reward 24.539473684210527
# Max reward so far:  74.0
# ==========================================
# Episode:  152
# Reward:  43.0
# Mean Reward 24.66013071895425
# Max reward so far:  74.0
# ==========================================
# Episode:  153
# Reward:  41.0
# Mean Reward 24.766233766233768
# Max reward so far:  74.0
# ==========================================
# Episode:  154
# Reward:  52.0
# Mean Reward 24.941935483870967
# Max reward so far:  74.0
# ==========================================
# Episode:  155
# Reward:  22.0
# Mean Reward 24.923076923076923
# Max reward so far:  74.0
# ==========================================
# Episode:  156
# Reward:  22.0
# Mean Reward 24.904458598726116
# Max reward so far:  74.0
# ==========================================
# Episode:  157
# Reward:  93.0
# Mean Reward 25.335443037974684
# Max reward so far:  93.0
# ==========================================
# Episode:  158
# Reward:  42.0
# Mean Reward 25.440251572327043
# Max reward so far:  93.0
# ==========================================
# Episode:  159
# Reward:  22.0
# Mean Reward 25.41875
# Max reward so far:  93.0
# ==========================================
# Episode:  160
# Reward:  22.0
# Mean Reward 25.39751552795031
# Max reward so far:  93.0
# ==========================================
# Episode:  161
# Reward:  22.0
# Mean Reward 25.376543209876544
# Max reward so far:  93.0
# ==========================================
# Episode:  162
# Reward:  22.0
# Mean Reward 25.355828220858896
# Max reward so far:  93.0
# ==========================================
# Episode:  163
# Reward:  44.0
# Mean Reward 25.46951219512195
# Max reward so far:  93.0
# ==========================================
# Episode:  164
# Reward:  16.0
# Mean Reward 25.412121212121214
# Max reward so far:  93.0
# ==========================================
# Episode:  165
# Reward:  45.0
# Mean Reward 25.53012048192771
# Max reward so far:  93.0
# ==========================================
# Episode:  166
# Reward:  31.0
# Mean Reward 25.562874251497007
# Max reward so far:  93.0
# ==========================================
# Episode:  167
# Reward:  49.0
# Mean Reward 25.702380952380953
# Max reward so far:  93.0
# ==========================================
# Episode:  168
# Reward:  42.0
# Mean Reward 25.798816568047336
# Max reward so far:  93.0
# ==========================================
# Episode:  169
# Reward:  36.0
# Mean Reward 25.858823529411765
# Max reward so far:  93.0
# ==========================================
# Episode:  170
# Reward:  23.0
# Mean Reward 25.842105263157894
# Max reward so far:  93.0
# ==========================================
# Episode:  171
# Reward:  15.0
# Mean Reward 25.77906976744186
# Max reward so far:  93.0
# ==========================================
# Episode:  172
# Reward:  27.0
# Mean Reward 25.786127167630056
# Max reward so far:  93.0
# ==========================================
# Episode:  173
# Reward:  14.0
# Mean Reward 25.7183908045977
# Max reward so far:  93.0
# ==========================================
# Episode:  174
# Reward:  34.0
# Mean Reward 25.765714285714285
# Max reward so far:  93.0
# ==========================================
# Episode:  175
# Reward:  42.0
# Mean Reward 25.857954545454547
# Max reward so far:  93.0
# ==========================================
# Episode:  176
# Reward:  14.0
# Mean Reward 25.7909604519774
# Max reward so far:  93.0
# ==========================================
# Episode:  177
# Reward:  98.0
# Mean Reward 26.196629213483146
# Max reward so far:  98.0
# ==========================================
# Episode:  178
# Reward:  66.0
# Mean Reward 26.41899441340782
# Max reward so far:  98.0
# ==========================================
# Episode:  179
# Reward:  25.0
# Mean Reward 26.41111111111111
# Max reward so far:  98.0
# ==========================================
# Episode:  180
# Reward:  52.0
# Mean Reward 26.552486187845304
# Max reward so far:  98.0
# ==========================================
# Episode:  181
# Reward:  40.0
# Mean Reward 26.626373626373628
# Max reward so far:  98.0
# ==========================================
# Episode:  182
# Reward:  16.0
# Mean Reward 26.56830601092896
# Max reward so far:  98.0
# ==========================================
# Episode:  183
# Reward:  15.0
# Mean Reward 26.505434782608695
# Max reward so far:  98.0
# ==========================================
# Episode:  184
# Reward:  30.0
# Mean Reward 26.524324324324326
# Max reward so far:  98.0
# ==========================================
# Episode:  185
# Reward:  15.0
# Mean Reward 26.462365591397848
# Max reward so far:  98.0
# ==========================================
# Episode:  186
# Reward:  42.0
# Mean Reward 26.545454545454547
# Max reward so far:  98.0
# ==========================================
# Episode:  187
# Reward:  39.0
# Mean Reward 26.611702127659573
# Max reward so far:  98.0
# ==========================================
# Episode:  188
# Reward:  30.0
# Mean Reward 26.62962962962963
# Max reward so far:  98.0
# ==========================================
# Episode:  189
# Reward:  45.0
# Mean Reward 26.726315789473684
# Max reward so far:  98.0
# ==========================================
# Episode:  190
# Reward:  31.0
# Mean Reward 26.74869109947644
# Max reward so far:  98.0
# ==========================================
# Episode:  191
# Reward:  35.0
# Mean Reward 26.791666666666668
# Max reward so far:  98.0
# ==========================================
# Episode:  192
# Reward:  46.0
# Mean Reward 26.89119170984456
# Max reward so far:  98.0
# ==========================================
# Episode:  193
# Reward:  35.0
# Mean Reward 26.932989690721648
# Max reward so far:  98.0
# ==========================================
# Episode:  194
# Reward:  15.0
# Mean Reward 26.871794871794872
# Max reward so far:  98.0
# ==========================================
# Episode:  195
# Reward:  27.0
# Mean Reward 26.872448979591837
# Max reward so far:  98.0
# ==========================================
# Episode:  196
# Reward:  29.0
# Mean Reward 26.883248730964468
# Max reward so far:  98.0
# ==========================================
# Episode:  197
# Reward:  55.0
# Mean Reward 27.025252525252526
# Max reward so far:  98.0
# ==========================================
# Episode:  198
# Reward:  24.0
# Mean Reward 27.01005025125628
# Max reward so far:  98.0
# ==========================================
# Episode:  199
# Reward:  57.0
# Mean Reward 27.16
# Max reward so far:  98.0
# ==========================================
# Episode:  200
# Reward:  33.0
# Mean Reward 27.18905472636816
# Max reward so far:  98.0
# Model saved
# ==========================================
# Episode:  201
# Reward:  40.0
# Mean Reward 27.252475247524753
# Max reward so far:  98.0
# ==========================================
# Episode:  202
# Reward:  27.0
# Mean Reward 27.251231527093594
# Max reward so far:  98.0
# ==========================================
# Episode:  203
# Reward:  44.0
# Mean Reward 27.333333333333332
# Max reward so far:  98.0
# ==========================================
# Episode:  204
# Reward:  64.0
# Mean Reward 27.51219512195122
# Max reward so far:  98.0
# ==========================================
# Episode:  205
# Reward:  49.0
# Mean Reward 27.616504854368934
# Max reward so far:  98.0
# ==========================================
# Episode:  206
# Reward:  19.0
# Mean Reward 27.57487922705314
# Max reward so far:  98.0
# ==========================================
# Episode:  207
# Reward:  62.0
# Mean Reward 27.740384615384617
# Max reward so far:  98.0
# ==========================================
# Episode:  208
# Reward:  19.0
# Mean Reward 27.698564593301434
# Max reward so far:  98.0
# ==========================================
# Episode:  209
# Reward:  54.0
# Mean Reward 27.823809523809523
# Max reward so far:  98.0
# ==========================================
# Episode:  210
# Reward:  66.0
# Mean Reward 28.00473933649289
# Max reward so far:  98.0
# ==========================================
# Episode:  211
# Reward:  21.0
# Mean Reward 27.971698113207548
# Max reward so far:  98.0
# ==========================================
# Episode:  212
# Reward:  18.0
# Mean Reward 27.92488262910798
# Max reward so far:  98.0
# ==========================================
# Episode:  213
# Reward:  30.0
# Mean Reward 27.934579439252335
# Max reward so far:  98.0
# ==========================================
# Episode:  214
# Reward:  42.0
# Mean Reward 28.0
# Max reward so far:  98.0
# ==========================================
# Episode:  215
# Reward:  48.0
# Mean Reward 28.09259259259259
# Max reward so far:  98.0
# ==========================================
# Episode:  216
# Reward:  72.0
# Mean Reward 28.294930875576036
# Max reward so far:  98.0
# ==========================================
# Episode:  217
# Reward:  48.0
# Mean Reward 28.38532110091743
# Max reward so far:  98.0
# ==========================================
# Episode:  218
# Reward:  49.0
# Mean Reward 28.47945205479452
# Max reward so far:  98.0
# ==========================================
# Episode:  219
# Reward:  39.0
# Mean Reward 28.527272727272727
# Max reward so far:  98.0
# ==========================================
# Episode:  220
# Reward:  19.0
# Mean Reward 28.4841628959276
# Max reward so far:  98.0
# ==========================================
# Episode:  221
# Reward:  28.0
# Mean Reward 28.48198198198198
# Max reward so far:  98.0
# ==========================================
# Episode:  222
# Reward:  48.0
# Mean Reward 28.569506726457398
# Max reward so far:  98.0
# ==========================================
# Episode:  223
# Reward:  17.0
# Mean Reward 28.517857142857142
# Max reward so far:  98.0
# ==========================================
# Episode:  224
# Reward:  38.0
# Mean Reward 28.56
# Max reward so far:  98.0
# ==========================================
# Episode:  225
# Reward:  82.0
# Mean Reward 28.79646017699115
# Max reward so far:  98.0
# ==========================================
# Episode:  226
# Reward:  72.0
# Mean Reward 28.986784140969164
# Max reward so far:  98.0
# ==========================================
# Episode:  227
# Reward:  46.0
# Mean Reward 29.06140350877193
# Max reward so far:  98.0
# ==========================================
# Episode:  228
# Reward:  15.0
# Mean Reward 29.0
# Max reward so far:  98.0
# ==========================================
# Episode:  229
# Reward:  13.0
# Mean Reward 28.930434782608696
# Max reward so far:  98.0
# ==========================================
# Episode:  230
# Reward:  20.0
# Mean Reward 28.89177489177489
# Max reward so far:  98.0
# ==========================================
# Episode:  231
# Reward:  53.0
# Mean Reward 28.995689655172413
# Max reward so far:  98.0
# ==========================================
# Episode:  232
# Reward:  89.0
# Mean Reward 29.253218884120173
# Max reward so far:  98.0
# ==========================================
# Episode:  233
# Reward:  26.0
# Mean Reward 29.23931623931624
# Max reward so far:  98.0
# ==========================================
# Episode:  234
# Reward:  34.0
# Mean Reward 29.259574468085106
# Max reward so far:  98.0
# ==========================================
# Episode:  235
# Reward:  16.0
# Mean Reward 29.203389830508474
# Max reward so far:  98.0
# ==========================================
# Episode:  236
# Reward:  23.0
# Mean Reward 29.17721518987342
# Max reward so far:  98.0
# ==========================================
# Episode:  237
# Reward:  72.0
# Mean Reward 29.357142857142858
# Max reward so far:  98.0
# ==========================================
# Episode:  238
# Reward:  26.0
# Mean Reward 29.343096234309623
# Max reward so far:  98.0
# ==========================================
# Episode:  239
# Reward:  150.0
# Mean Reward 29.845833333333335
# Max reward so far:  150.0
# ==========================================
# Episode:  240
# Reward:  108.0
# Mean Reward 30.1701244813278
# Max reward so far:  150.0
# ==========================================
# Episode:  241
# Reward:  20.0
# Mean Reward 30.128099173553718
# Max reward so far:  150.0
# ==========================================
# Episode:  242
# Reward:  131.0
# Mean Reward 30.54320987654321
# Max reward so far:  150.0
# ==========================================
# Episode:  243
# Reward:  141.0
# Mean Reward 30.99590163934426
# Max reward so far:  150.0
# ==========================================
# Episode:  244
# Reward:  138.0
# Mean Reward 31.43265306122449
# Max reward so far:  150.0
# ==========================================
# Episode:  245
# Reward:  130.0
# Mean Reward 31.833333333333332
# Max reward so far:  150.0
# ==========================================
# Episode:  246
# Reward:  110.0
# Mean Reward 32.149797570850204
# Max reward so far:  150.0
# ==========================================
# Episode:  247
# Reward:  58.0
# Mean Reward 32.25403225806452
# Max reward so far:  150.0
# ==========================================
# Episode:  248
# Reward:  170.0
# Mean Reward 32.80722891566265
# Max reward so far:  170.0
# ==========================================
# Episode:  249
# Reward:  81.0
# Mean Reward 33.0
# Max reward so far:  170.0
# ==========================================
# Episode:  250
# Reward:  357.0
# Mean Reward 34.29083665338646
# Max reward so far:  357.0
# ==========================================
# Episode:  251
# Reward:  76.0
# Mean Reward 34.45634920634921
# Max reward so far:  357.0
# ==========================================
# Episode:  252
# Reward:  200.0
# Mean Reward 35.11067193675889
# Max reward so far:  357.0
# ==========================================
# Episode:  253
# Reward:  290.0
# Mean Reward 36.11417322834646
# Max reward so far:  357.0
# ==========================================
# Episode:  254
# Reward:  140.0
# Mean Reward 36.52156862745098
# Max reward so far:  357.0
# ==========================================
# Episode:  255
# Reward:  242.0
# Mean Reward 37.32421875
# Max reward so far:  357.0
# ==========================================
# Episode:  256
# Reward:  34.0
# Mean Reward 37.311284046692606
# Max reward so far:  357.0
# ==========================================
# Episode:  257
# Reward:  63.0
# Mean Reward 37.41085271317829
# Max reward so far:  357.0
# ==========================================
# Episode:  258
# Reward:  169.0
# Mean Reward 37.91891891891892
# Max reward so far:  357.0
# ==========================================
# Episode:  259
# Reward:  89.0
# Mean Reward 38.11538461538461
# Max reward so far:  357.0
# ==========================================
# Episode:  260
# Reward:  135.0
# Mean Reward 38.486590038314176
# Max reward so far:  357.0
# ==========================================
# Episode:  261
# Reward:  150.0
# Mean Reward 38.912213740458014
# Max reward so far:  357.0
# ==========================================
# Episode:  262
# Reward:  129.0
# Mean Reward 39.254752851711025
# Max reward so far:  357.0
# ==========================================
# Episode:  263
# Reward:  33.0
# Mean Reward 39.23106060606061
# Max reward so far:  357.0
# ==========================================
# Episode:  264
# Reward:  201.0
# Mean Reward 39.841509433962266
# Max reward so far:  357.0
# ==========================================
# Episode:  265
# Reward:  178.0
# Mean Reward 40.3609022556391
# Max reward so far:  357.0
# ==========================================
# Episode:  266
# Reward:  131.0
# Mean Reward 40.70037453183521
# Max reward so far:  357.0
# ==========================================
# Episode:  267
# Reward:  57.0
# Mean Reward 40.76119402985075
# Max reward so far:  357.0
# ==========================================
# Episode:  268
# Reward:  538.0
# Mean Reward 42.60966542750929
# Max reward so far:  538.0
# ==========================================
# Episode:  269
# Reward:  201.0
# Mean Reward 43.196296296296296
# Max reward so far:  538.0
# ==========================================
# Episode:  270
# Reward:  749.0
# Mean Reward 45.800738007380076
# Max reward so far:  749.0
# ==========================================
# Episode:  271
# Reward:  161.0
# Mean Reward 46.224264705882355
# Max reward so far:  749.0
# ==========================================
# Episode:  272
# Reward:  151.0
# Mean Reward 46.608058608058606
# Max reward so far:  749.0
# ==========================================
# Episode:  273
# Reward:  119.0
# Mean Reward 46.872262773722625
# Max reward so far:  749.0
# ==========================================
# Episode:  274
# Reward:  265.0
# Mean Reward 47.665454545454544
# Max reward so far:  749.0
# ==========================================
# Episode:  275
# Reward:  187.0
# Mean Reward 48.17028985507246
# Max reward so far:  749.0
# ==========================================
# Episode:  276
# Reward:  281.0
# Mean Reward 49.01083032490975
# Max reward so far:  749.0
# ==========================================
# Episode:  277
# Reward:  254.0
# Mean Reward 49.74820143884892
# Max reward so far:  749.0
# ==========================================
# Episode:  278
# Reward:  116.0
# Mean Reward 49.98566308243728
# Max reward so far:  749.0
# ==========================================
# Episode:  279
# Reward:  304.0
# Mean Reward 50.892857142857146
# Max reward so far:  749.0
# ==========================================
# Episode:  280
# Reward:  127.0
# Mean Reward 51.163701067615655
# Max reward so far:  749.0
# ==========================================
# Episode:  281
# Reward:  133.0
# Mean Reward 51.45390070921986
# Max reward so far:  749.0
# ==========================================
# Episode:  282
# Reward:  431.0
# Mean Reward 52.79505300353357
# Max reward so far:  749.0
# ==========================================
# Episode:  283
# Reward:  277.0
# Mean Reward 53.58450704225352
# Max reward so far:  749.0
# ==========================================
# Episode:  284
# Reward:  170.0
# Mean Reward 53.99298245614035
# Max reward so far:  749.0
# ==========================================
# Episode:  285
# Reward:  99.0
# Mean Reward 54.15034965034965
# Max reward so far:  749.0
# ==========================================
# Episode:  286
# Reward:  193.0
# Mean Reward 54.63414634146341
# Max reward so far:  749.0
# ==========================================
# Episode:  287
# Reward:  529.0
# Mean Reward 56.28125
# Max reward so far:  749.0
# ==========================================
# Episode:  288
# Reward:  153.0
# Mean Reward 56.6159169550173
# Max reward so far:  749.0
# ==========================================
# Episode:  289
# Reward:  61.0
# Mean Reward 56.63103448275862
# Max reward so far:  749.0
# ==========================================
# Episode:  290
# Reward:  161.0
# Mean Reward 56.98969072164948
# Max reward so far:  749.0
# ==========================================
# Episode:  291
# Reward:  13.0
# Mean Reward 56.83904109589041
# Max reward so far:  749.0
# ==========================================
# Episode:  292
# Reward:  285.0
# Mean Reward 57.617747440273035
# Max reward so far:  749.0
# ==========================================
# Episode:  293
# Reward:  371.0
# Mean Reward 58.683673469387756
# Max reward so far:  749.0
# ==========================================
# Episode:  294
# Reward:  813.0
# Mean Reward 61.24067796610169
# Max reward so far:  813.0
# ==========================================
# Episode:  295
# Reward:  394.0
# Mean Reward 62.36486486486486
# Max reward so far:  813.0
# ==========================================
# Episode:  296
# Reward:  492.0
# Mean Reward 63.81144781144781
# Max reward so far:  813.0
# ==========================================
# Episode:  297
# Reward:  34.0
# Mean Reward 63.711409395973156
# Max reward so far:  813.0
# ==========================================
# Episode:  298
# Reward:  998.0
# Mean Reward 66.8361204013378
# Max reward so far:  998.0
# ==========================================
# Episode:  299
# Reward:  112.0
# Mean Reward 66.98666666666666
# Max reward so far:  998.0

# %%
with tf.Session() as sess:
    env.reset()
    rewards = []
    
    # Load the model
    saver.restore(sess, "./models/model.ckpt")

    for episode in range(10):
        state = env.reset()
        step = 0
        done = False
        total_rewards = 0
        print("****************************************************")
        print("EPISODE ", episode)

        while True:
            

            # Choose action a, remember WE'RE NOT IN A DETERMINISTIC ENVIRONMENT, WE'RE OUTPUT PROBABILITIES.
            action_probability_distribution = sess.run(action_distribution, feed_dict={input_: state.reshape([1,4])})
            #print(action_probability_distribution)
            action = np.random.choice(range(action_probability_distribution.shape[1]), p=action_probability_distribution.ravel())  # select action w.r.t the actions prob


            new_state, reward, done, info = env.step(action)

            total_rewards += reward

            if done:
                rewards.append(total_rewards)
                print ("Score", total_rewards)
                break
            state = new_state
    env.close()
    print ("Score over time: " +  str(sum(rewards)/10))
# Out:
# INFO:tensorflow:Restoring parameters from ./models/model.ckpt
# ****************************************************
# EPISODE  0
# Score 77.0
# ****************************************************
# EPISODE  1
# Score 101.0
# ****************************************************
# EPISODE  2
# Score 92.0
# ****************************************************
# EPISODE  3
# Score 43.0
# ****************************************************
# EPISODE  4
# Score 73.0
# ****************************************************
# EPISODE  5
# Score 44.0
# ****************************************************
# EPISODE  6
# Score 63.0
# ****************************************************
# EPISODE  7
# Score 47.0
# ****************************************************
# EPISODE  8
# Score 16.0
# ****************************************************
# EPISODE  9
# Score 32.0
# Score over time: 58.8
